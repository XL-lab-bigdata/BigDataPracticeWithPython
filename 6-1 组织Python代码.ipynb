# %% [markdown]
# # 6 组织Python代码

# %% [markdown]
# ## 6.1概述

# %% [markdown]
# ### 6.1.1模块

# %%
import demotxt
print(demotxt.name)
# Out:
# 导入成功
# Python大数据编程

# %% [markdown]
# ### 6.1.2包

# %% [markdown]
# #### (1)传统包

# %%
import demo_tradition.foo
demo_tradition.foo
# Out:
# <module 'demo.foo' from 'C:\\Users\\87209\\Desktop\\Python\\第六章代码\\demo\\foo\\__init__.py'>

# %%
import demo_tradition.bar
demo_tradition.bar
# Out:
# <module 'demo.bar' from 'C:\\Users\\87209\\Desktop\\Python\\第六章代码\\demo\\bar\\__init__.py'>

# %%
from demo_tradition import foo
foo
# Out:
# <module 'demo.foo' from 'C:\\Users\\87209\\Desktop\\Python\\第六章代码\\demo\\foo\\__init__.py'>

# %%
from demo_tradition import bar
bar
# Out:
# <module 'demo.bar' from 'C:\\Users\\87209\\Desktop\\Python\\第六章代码\\demo\\bar\\__init__.py'>

# %% [markdown]
# #### (2)命名空间包

# %%
import demo_namespace
import demo_namespace.foo
import demo_namespace.bar

# %%
demo_namespace
# Out:
# <module 'demo_namespace' (namespace)>

# %%
demo_namespace.__path__
# Out:
# _NamespacePath(['C:\\Users\\87209\\Desktop\\Python\\第六章代码\\demo_namespace', 'C:\\Users\\87209\\Desktop\\Python\\第六章代码\\demo_namespace'])

# %% [markdown]
# ##### 包的合并

# %%
'''
此代码需要在命令行窗口运行
'''
import sys
sys.path.extend(['xc-pkg','xm-pkg'])
import demo
demo
demo.__path__

# %% [markdown]
# ## 6.2导入

# %% [markdown]
# > 注：本部分仅供参考，无需运行

# %% [markdown]
# #### (1)import 语句应当分行书写。

# %%
# bad
import os,sys

# good
import os
import sys

# %% [markdown]
# #### (2)import语句应当使用绝对导入

# %%
# bad
from ..bar import  Bar

# good
from foo.bar import test

# %% [markdown]
# #### (3)import语句应当放在文件头部，置于模块说明及文档字符串之后，全局变量之前。

# %% [markdown]
# #### (4)import语句应该按照顺序排列，每组之间用一个空格分隔，按照内置模块，第三方模块，自己所写的模块调用顺序，同时每组内部按照字母表顺序排列。

# %%
# 内置模块
import os
import sys
# 第三方模块
import flask
# 本地模块
from foo import bar
